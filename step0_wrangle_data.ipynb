# %%
import re
import glob

# data dir
data_dir = './traffic_anomalies_data/'
out_dir = './temp/'
file_number = 0

for original_file in glob.glob(f'{data_dir}*.TXT'):
    with open(original_file, 'r') as file:
        content = file.read()
    file_number += 1
    rm_strings = ['SAS Output', 'Minnesota Department of Transportation', 'Continuous Count Station Edited Data for', 
                  'Hour Ending At:', '* - Day Contains Some or All Estimated Data Due to Missing Data or Malfunctions at the ATR.', 
                  'DATE         DAY       1 am  2 am  3 am  4 am 5 am  6 am  7 am  8 am  9 am 10 am 11 am  Noon  1 pm  2 pm  3 pm  4 pm  5 pm  6 pm  7 pm  8 pm  9 pm 10 pm 11 pm 12 mid TOTAL', 
                  'DATE         DAY       HR1   HR2   HR3   HR4  HR5   HR6   HR7   HR8   HR9  HR10  HR11  HR12  HR13  HR14  HR15  HR16  HR17  HR18  HR19  HR20  HR21  HR22  HR23  HR24 TOTAL']
    for rm_str in rm_strings:
        content = content.replace(rm_str, '')
    # remove redundant spaces
    content = re.sub(r' +', ' ', content)
    # remove redundant newlines
    content = re.sub(r'\n+', '\n', content)
    # remove dashes
    content = re.sub(r'-+', '', content)
    # fix rows with leading space
    content = re.sub(r'\n ', '\n', content)
    # fix double newlines
    content = re.sub(r'\n\n', '\n', content)
    # remove *
    content = re.sub(r'\* ', '', content)

    # months
    months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    directions = ['East', 'West']
    for month in months:
        for direction in directions:
            try:
                table = re.search(f'Station 301, Direction {direction}, {month}([\s\S]*?)AVERAGES', content).group(1)
                # strip leading and trailing whitespace
                table = table.strip()
                file_name = f'{out_dir}{file_number}_{direction}_{month}.txt'
                with open(file_name, 'w') as text_file:
                    text_file.write(table)
            except AttributeError:
                print(f'Station 301, Direction {direction}, {month}([\s\S]*?)AVERAGES')
                print('FAILED')
# Out:
# Station 301, Direction East, October([\s\S]*?)AVERAGES
# FAILED
# Station 301, Direction West, October([\s\S]*?)AVERAGES
# FAILED
# Station 301, Direction East, November([\s\S]*?)AVERAGES
# FAILED
# Station 301, Direction West, November([\s\S]*?)AVERAGES
# FAILED
# Station 301, Direction East, December([\s\S]*?)AVERAGES
# FAILED
# Station 301, Direction West, December([\s\S]*?)AVERAGES
# FAILED

# %%
import pandas as pd


directions = ['East', 'West']
for direction in directions:
    master_df = pd.DataFrame()
    for original_file in glob.glob(f'{out_dir}*{direction}*.txt'):
        print(original_file)
        df = pd.read_csv(original_file, sep=' ', header=None)
        print(df.shape)
        print(master_df.shape)
        master_df = pd.concat([master_df, df])
        print(master_df.shape)
    # rename the columns
    ew = direction[0]
    # shifted the time from the official data by 1 hour so it 'starts at' the following time
    master_df.columns = ['Month', 'Day', 'Year', 'Week_Day', '00:00', '01:00', '02:00', '03:00', '04:00', '05:00', 
                         '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', 
                         '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', 
                         '20:00', '21:00', '22:00', '23:00', 'Total']
    # combine the first three into a date
    master_df['Date'] = master_df['Month'] + ' ' + master_df['Day'].astype('str') + ' ' + master_df['Year'].astype('str')
    master_df['Date'] = pd.to_datetime(master_df['Date'], format='%b %d, %Y')
    del master_df['Month'] 
    del master_df['Day']
    del master_df['Year']
    del master_df['Week_Day']
    master_df['Date'] = pd.to_datetime(master_df['Date'])
    master_df['Day_of_Week'] = master_df['Date'].dt.dayofweek
    master_df['Year'] = master_df['Date'].dt.year
    master_df['Month'] = master_df['Date'].dt.month
    master_df['Week_of_Year'] = master_df['Date'].dt.week
    master_df['Day_of_Month'] = master_df['Date'].dt.day
    master_df.to_csv(f'Station_301_{direction}.csv.gz', index=False, compression='gzip')
# Out:
# ./temp\10_East_April.txt
# (30, 29)
# (0, 0)
# (30, 29)
# ./temp\10_East_August.txt
# (31, 29)
# (30, 29)
# (61, 29)
# ./temp\10_East_December.txt
# (31, 29)
# (61, 29)
# (92, 29)
# ./temp\10_East_February.txt
# (28, 29)
# (92, 29)
# (120, 29)
# ./temp\10_East_January.txt
# (31, 29)
# (120, 29)
# (151, 29)
# ./temp\10_East_July.txt
# (31, 29)
# (151, 29)
# (182, 29)
# ./temp\10_East_June.txt
# (30, 29)
# (182, 29)
# (212, 29)
# ./temp\10_East_March.txt
# (31, 29)
# (212, 29)
# (243, 29)
# ./temp\10_East_May.txt
# (31, 29)
# (243, 29)
# (274, 29)
# ./temp\10_East_November.txt
# (30, 29)
# (274, 29)
# (304, 29)
# ./temp\10_East_October.txt
# (31, 29)
# (304, 29)
# (335, 29)
# ./temp\10_East_September.txt
# (30, 29)
# (335, 29)
# (365, 29)
# ./temp\11_East_April.txt
# (30, 29)
# (365, 29)
# (395, 29)
# ./temp\11_East_August.txt
# (31, 29)
# (395, 29)
# (426, 29)
# ./temp\11_East_December.txt
# (31, 29)
# (426, 29)
# (457, 29)
# ./temp\11_East_February.txt
# (29, 29)
# (457, 29)
# (486, 29)
# ./temp\11_East_January.txt
# (31, 29)
# (486, 29)
# (517, 29)
# ./temp\11_East_July.txt
# (31, 29)
# (517, 29)
# (548, 29)
# ./temp\11_East_June.txt
# (30, 29)
# (548, 29)
# (578, 29)
# ./temp\11_East_March.txt
# (31, 29)
# (578, 29)
# (609, 29)
# ./temp\11_East_May.txt
# (31, 29)
# (609, 29)
# (640, 29)
# ./temp\11_East_November.txt
# (30, 29)
# (640, 29)
# (670, 29)
# ./temp\11_East_October.txt
# (31, 29)
# (670, 29)
# (701, 29)
# ./temp\11_East_September.txt
# (30, 29)
# (701, 29)
# (731, 29)
# ./temp\12_East_April.txt
# (30, 29)
# (731, 29)
# (761, 29)
# ./temp\12_East_August.txt
# (31, 29)
# (761, 29)
# (792, 29)
# ./temp\12_East_December.txt
# (31, 29)
# (792, 29)
# (823, 29)
# ./temp\12_East_February.txt
# (28, 29)
# (823, 29)
# (851, 29)
# ./temp\12_East_January.txt
# (31, 29)
# (851, 29)
# (882, 29)
# ./temp\12_East_July.txt
# (31, 29)
# (882, 29)
# (913, 29)
# ./temp\12_East_June.txt
# (30, 29)
# (913, 29)
# (943, 29)
# ./temp\12_East_March.txt
# (31, 29)
# (943, 29)
# (974, 29)
# ./temp\12_East_May.txt
# (31, 29)
# (974, 29)
# (1005, 29)
# ./temp\12_East_November.txt
# (30, 29)
# (1005, 29)
# (1035, 29)
# ./temp\12_East_October.txt
# (31, 29)
# (1035, 29)
# (1066, 29)
# ./temp\12_East_September.txt
# (30, 29)
# (1066, 29)
# (1096, 29)
# ./temp\13_East_April.txt
# (30, 29)
# (1096, 29)
# (1126, 29)
# ./temp\13_East_August.txt
# (31, 29)
# (1126, 29)
# (1157, 29)
# ./temp\13_East_December.txt
# (31, 29)
# (1157, 29)
# (1188, 29)
# ./temp\13_East_February.txt
# (28, 29)
# (1188, 29)
# (1216, 29)
# ./temp\13_East_January.txt
# (31, 29)
# (1216, 29)
# (1247, 29)
# ./temp\13_East_July.txt
# (31, 29)
# (1247, 29)
# (1278, 29)
# ./temp\13_East_June.txt
# (30, 29)
# (1278, 29)
# (1308, 29)
# ./temp\13_East_March.txt
# (31, 29)
# (1308, 29)
# (1339, 29)
# ./temp\13_East_May.txt
# (31, 29)
# (1339, 29)
# (1370, 29)
# ./temp\13_East_November.txt
# (30, 29)
# (1370, 29)
# (1400, 29)
# ./temp\13_East_October.txt
# (31, 29)
# (1400, 29)
# (1431, 29)
# ./temp\13_East_September.txt
# (30, 29)
# (1431, 29)
# (1461, 29)
# ./temp\14_East_April.txt
# (30, 29)
# (1461, 29)
# (1491, 29)
# ./temp\14_East_August.txt
# (31, 29)
# (1491, 29)
# (1522, 29)
# ./temp\14_East_December.txt
# (31, 29)
# (1522, 29)
# (1553, 29)
# ./temp\14_East_February.txt
# (28, 29)
# (1553, 29)
# (1581, 29)
# ./temp\14_East_January.txt
# (31, 29)
# (1581, 29)
# (1612, 29)
# ./temp\14_East_July.txt
# (31, 29)
# (1612, 29)
# (1643, 29)
# ./temp\14_East_June.txt
# (30, 29)
# (1643, 29)
# (1673, 29)
# ./temp\14_East_March.txt
# (31, 29)
# (1673, 29)
# (1704, 29)
# ./temp\14_East_May.txt
# (31, 29)
# (1704, 29)
# (1735, 29)
# ./temp\14_East_November.txt
# (30, 29)
# (1735, 29)
# (1765, 29)
# ./temp\14_East_October.txt
# (31, 29)
# (1765, 29)
# (1796, 29)
# ./temp\14_East_September.txt
# (30, 29)
# (1796, 29)
# (1826, 29)
# ./temp\15_East_April.txt
# (30, 29)
# (1826, 29)
# (1856, 29)
# ./temp\15_East_August.txt
# (31, 29)
# (1856, 29)
# (1887, 29)
# ./temp\15_East_December.txt
# (31, 29)
# (1887, 29)
# (1918, 29)
# ./temp\15_East_February.txt
# (29, 29)
# (1918, 29)
# (1947, 29)
# ./temp\15_East_January.txt
# (31, 29)
# (1947, 29)
# (1978, 29)
# ./temp\15_East_July.txt
# (31, 29)
# (1978, 29)
# (2009, 29)
# ./temp\15_East_June.txt
# (30, 29)
# (2009, 29)
# (2039, 29)
# ./temp\15_East_March.txt
# (31, 29)
# (2039, 29)
# (2070, 29)
# ./temp\15_East_May.txt
# (31, 29)
# (2070, 29)
# (2101, 29)
# ./temp\15_East_November.txt
# (30, 29)
# (2101, 29)
# (2131, 29)
# ./temp\15_East_October.txt
# (31, 29)
# (2131, 29)
# (2162, 29)
# ./temp\15_East_September.txt
# (30, 29)
# (2162, 29)
# (2192, 29)
# ./temp\16_East_April.txt
# (30, 29)
# (2192, 29)
# (2222, 29)
# ./temp\16_East_August.txt
# (31, 29)
# (2222, 29)
# (2253, 29)
# ./temp\16_East_December.txt
# (31, 29)
# (2253, 29)
# (2284, 29)
# ./temp\16_East_February.txt
# (28, 29)
# (2284, 29)
# (2312, 29)
# ./temp\16_East_January.txt
# (31, 29)
# (2312, 29)
# (2343, 29)
# ./temp\16_East_July.txt
# (31, 29)
# (2343, 29)
# (2374, 29)
# ./temp\16_East_June.txt
# (30, 29)
# (2374, 29)
# (2404, 29)
# ./temp\16_East_March.txt
# (31, 29)
# (2404, 29)
# (2435, 29)
# ./temp\16_East_May.txt
# (31, 29)
# (2435, 29)
# (2466, 29)
# ./temp\16_East_November.txt
# (30, 29)
# (2466, 29)
# (2496, 29)
# ./temp\16_East_October.txt
# (31, 29)
# (2496, 29)
# (2527, 29)
# ./temp\16_East_September.txt
# (30, 29)
# (2527, 29)
# (2557, 29)
# ./temp\17_East_April.txt
# (30, 29)
# (2557, 29)
# (2587, 29)
# ./temp\17_East_August.txt
# (31, 29)
# (2587, 29)
# (2618, 29)
# ./temp\17_East_February.txt
# (28, 29)
# (2618, 29)
# (2646, 29)
# ./temp\17_East_January.txt
# (31, 29)
# (2646, 29)
# (2677, 29)
# ./temp\17_East_July.txt
# (31, 29)
# (2677, 29)
# (2708, 29)
# ./temp\17_East_June.txt
# (30, 29)
# (2708, 29)
# (2738, 29)
# ./temp\17_East_March.txt
# (31, 29)
# (2738, 29)
# (2769, 29)
# ./temp\17_East_May.txt
# (31, 29)
# (2769, 29)
# (2800, 29)
# ./temp\17_East_September.txt
# (30, 29)
# (2800, 29)
# (2830, 29)
# ./temp\1_East_April.txt
# (30, 29)
# (2830, 29)
# (2860, 29)
# ./temp\1_East_August.txt
# (31, 29)
# (2860, 29)
# (2891, 29)
# ./temp\1_East_December.txt
# (31, 29)
# (2891, 29)
# (2922, 29)
# ./temp\1_East_February.txt
# (28, 29)
# (2922, 29)
# (2950, 29)
# ./temp\1_East_January.txt
# (31, 29)
# (2950, 29)
# (2981, 29)
# ./temp\1_East_July.txt
# (31, 29)
# (2981, 29)
# (3012, 29)
# ./temp\1_East_June.txt
# (30, 29)
# (3012, 29)
# (3042, 29)
# ./temp\1_East_March.txt
# (31, 29)
# (3042, 29)
# (3073, 29)
# ./temp\1_East_May.txt
# (31, 29)
# (3073, 29)
# (3104, 29)
# ./temp\1_East_November.txt
# (30, 29)
# (3104, 29)
# (3134, 29)
# ./temp\1_East_October.txt
# (31, 29)
# (3134, 29)
# (3165, 29)
# ./temp\1_East_September.txt
# (30, 29)
# (3165, 29)
# (3195, 29)
# ./temp\2_East_April.txt
# (30, 29)
# (3195, 29)
# (3225, 29)
# ./temp\2_East_August.txt
# (31, 29)
# (3225, 29)
# (3256, 29)
# ./temp\2_East_December.txt
# (31, 29)
# (3256, 29)
# (3287, 29)
# ./temp\2_East_February.txt
# (28, 29)
# (3287, 29)
# (3315, 29)
# ./temp\2_East_January.txt
# (31, 29)
# (3315, 29)
# (3346, 29)
# ./temp\2_East_July.txt
# (31, 29)
# (3346, 29)
# (3377, 29)
# ./temp\2_East_June.txt
# (30, 29)
# (3377, 29)
# (3407, 29)
# ./temp\2_East_March.txt
# (31, 29)
# (3407, 29)
# (3438, 29)
# ./temp\2_East_May.txt
# (31, 29)
# (3438, 29)
# (3469, 29)
# ./temp\2_East_November.txt
# (30, 29)
# (3469, 29)
# (3499, 29)
# ./temp\2_East_October.txt
# (31, 29)
# (3499, 29)
# (3530, 29)
# ./temp\2_East_September.txt
# (30, 29)
# (3530, 29)
# (3560, 29)
# ./temp\3_East_April.txt
# (30, 29)
# (3560, 29)
# (3590, 29)
# ./temp\3_East_August.txt
# (31, 29)
# (3590, 29)
# (3621, 29)
# ./temp\3_East_December.txt
# (31, 29)
# (3621, 29)
# (3652, 29)
# ./temp\3_East_February.txt
# (29, 29)
# (3652, 29)
# (3681, 29)
# ./temp\3_East_January.txt
# (31, 29)
# (3681, 29)
# (3712, 29)
# ./temp\3_East_July.txt
# (31, 29)
# (3712, 29)
# (3743, 29)
# ./temp\3_East_June.txt
# (30, 29)
# (3743, 29)
# (3773, 29)
# ./temp\3_East_March.txt
# (31, 29)
# (3773, 29)
# (3804, 29)
# ./temp\3_East_May.txt
# (31, 29)
# (3804, 29)
# (3835, 29)
# ./temp\3_East_November.txt
# (30, 29)
# (3835, 29)
# (3865, 29)
# ./temp\3_East_October.txt
# (31, 29)
# (3865, 29)
# (3896, 29)
# ./temp\3_East_September.txt
# (30, 29)
# (3896, 29)
# (3926, 29)
# ./temp\4_East_April.txt
# (30, 29)
# (3926, 29)
# (3956, 29)
# ./temp\4_East_August.txt
# (31, 29)
# (3956, 29)
# (3987, 29)
# ./temp\4_East_December.txt
# (31, 29)
# (3987, 29)
# (4018, 29)
# ./temp\4_East_February.txt
# (28, 29)
# (4018, 29)
# (4046, 29)
# ./temp\4_East_January.txt
# (31, 29)
# (4046, 29)
# (4077, 29)
# ./temp\4_East_July.txt
# (31, 29)
# (4077, 29)
# (4108, 29)
# ./temp\4_East_June.txt
# (30, 29)
# (4108, 29)
# (4138, 29)
# ./temp\4_East_March.txt
# (31, 29)
# (4138, 29)
# (4169, 29)
# ./temp\4_East_May.txt
# (31, 29)
# (4169, 29)
# (4200, 29)
# ./temp\4_East_November.txt
# (30, 29)
# (4200, 29)
# (4230, 29)
# ./temp\4_East_October.txt
# (31, 29)
# (4230, 29)
# (4261, 29)
# ./temp\4_East_September.txt
# (30, 29)
# (4261, 29)
# (4291, 29)
# ./temp\5_East_April.txt
# (30, 29)
# (4291, 29)
# (4321, 29)
# ./temp\5_East_August.txt
# (31, 29)
# (4321, 29)
# (4352, 29)
# ./temp\5_East_December.txt
# (31, 29)
# (4352, 29)
# (4383, 29)
# ./temp\5_East_February.txt
# (28, 29)
# (4383, 29)
# (4411, 29)
# ./temp\5_East_January.txt
# (31, 29)
# (4411, 29)
# (4442, 29)
# ./temp\5_East_July.txt
# (31, 29)
# (4442, 29)
# (4473, 29)
# ./temp\5_East_June.txt
# (30, 29)
# (4473, 29)
# (4503, 29)
# ./temp\5_East_March.txt
# (31, 29)
# (4503, 29)
# (4534, 29)
# ./temp\5_East_May.txt
# (31, 29)
# (4534, 29)
# (4565, 29)
# ./temp\5_East_November.txt
# (30, 29)
# (4565, 29)
# (4595, 29)
# ./temp\5_East_October.txt
# (31, 29)
# (4595, 29)
# (4626, 29)
# ./temp\5_East_September.txt
# (30, 29)
# (4626, 29)
# (4656, 29)
# ./temp\6_East_April.txt
# (30, 29)
# (4656, 29)
# (4686, 29)
# ./temp\6_East_August.txt
# (31, 29)
# (4686, 29)
# (4717, 29)
# ./temp\6_East_December.txt
# (31, 29)
# (4717, 29)
# (4748, 29)
# ./temp\6_East_February.txt
# (28, 29)
# (4748, 29)
# (4776, 29)
# ./temp\6_East_January.txt
# (31, 29)
# (4776, 29)
# (4807, 29)
# ./temp\6_East_July.txt
# (31, 29)
# (4807, 29)
# (4838, 29)
# ./temp\6_East_June.txt
# (30, 29)
# (4838, 29)
# (4868, 29)
# ./temp\6_East_March.txt
# (31, 29)
# (4868, 29)
# (4899, 29)
# ./temp\6_East_May.txt
# (31, 29)
# (4899, 29)
# (4930, 29)
# ./temp\6_East_November.txt
# (30, 29)
# (4930, 29)
# (4960, 29)
# ./temp\6_East_October.txt
# (31, 29)
# (4960, 29)
# (4991, 29)
# ./temp\6_East_September.txt
# (30, 29)
# (4991, 29)
# (5021, 29)
# ./temp\7_East_April.txt
# (30, 29)
# (5021, 29)
# (5051, 29)
# ./temp\7_East_August.txt
# (31, 29)
# (5051, 29)
# (5082, 29)
# ./temp\7_East_December.txt
# (31, 29)
# (5082, 29)
# (5113, 29)
# ./temp\7_East_February.txt
# (29, 29)
# (5113, 29)
# (5142, 29)
# ./temp\7_East_January.txt
# (31, 29)
# (5142, 29)
# (5173, 29)
# ./temp\7_East_July.txt
# (31, 29)
# (5173, 29)
# (5204, 29)
# ./temp\7_East_June.txt
# (30, 29)
# (5204, 29)
# (5234, 29)
# ./temp\7_East_March.txt
# (31, 29)
# (5234, 29)
# (5265, 29)
# ./temp\7_East_May.txt
# (31, 29)
# (5265, 29)
# (5296, 29)
# ./temp\7_East_November.txt
# (30, 29)
# (5296, 29)
# (5326, 29)
# ./temp\7_East_October.txt
# (31, 29)
# (5326, 29)
# (5357, 29)
# ./temp\7_East_September.txt
# (30, 29)
# (5357, 29)
# (5387, 29)
# ./temp\8_East_April.txt
# (30, 29)
# (5387, 29)
# (5417, 29)
# ./temp\8_East_August.txt
# (31, 29)
# (5417, 29)
# (5448, 29)
# ./temp\8_East_December.txt
# (31, 29)
# (5448, 29)
# (5479, 29)
# ./temp\8_East_February.txt
# (28, 29)
# (5479, 29)
# (5507, 29)
# ./temp\8_East_January.txt
# (31, 29)
# (5507, 29)
# (5538, 29)
# ./temp\8_East_July.txt
# (31, 29)
# (5538, 29)
# (5569, 29)
# ./temp\8_East_June.txt
# (30, 29)
# (5569, 29)
# (5599, 29)
# ./temp\8_East_March.txt
# (31, 29)
# (5599, 29)
# (5630, 29)
# ./temp\8_East_May.txt
# (31, 29)
# (5630, 29)
# (5661, 29)
# ./temp\8_East_November.txt
# (30, 29)
# (5661, 29)
# (5691, 29)
# ./temp\8_East_October.txt
# (31, 29)
# (5691, 29)
# (5722, 29)
# ./temp\8_East_September.txt
# (30, 29)
# (5722, 29)
# (5752, 29)
# ./temp\9_East_April.txt
# (30, 29)
# (5752, 29)
# (5782, 29)
# ./temp\9_East_August.txt
# (31, 29)
# (5782, 29)
# (5813, 29)
# ./temp\9_East_December.txt
# (31, 29)
# (5813, 29)
# (5844, 29)
# ./temp\9_East_February.txt
# (28, 29)
# (5844, 29)
# (5872, 29)
# ./temp\9_East_January.txt
# (31, 29)
# (5872, 29)
# (5903, 29)
# ./temp\9_East_July.txt
# (31, 29)
# (5903, 29)
# (5934, 29)
# ./temp\9_East_June.txt
# (30, 29)
# (5934, 29)
# (5964, 29)
# ./temp\9_East_March.txt
# (31, 29)
# (5964, 29)
# (5995, 29)
# ./temp\9_East_May.txt
# (31, 29)
# (5995, 29)
# (6026, 29)
# ./temp\9_East_November.txt
# (30, 29)
# (6026, 29)
# (6056, 29)
# ./temp\9_East_October.txt
# (31, 29)
# (6056, 29)
# (6087, 29)
# ./temp\9_East_September.txt
# (30, 29)
# (6087, 29)
# (6117, 29)
# ./temp\10_West_April.txt
# (30, 29)
# (0, 0)
# (30, 29)
# ./temp\10_West_August.txt
# (31, 29)
# (30, 29)
# (61, 29)
# ./temp\10_West_December.txt
# (31, 29)
# (61, 29)
# (92, 29)
# ./temp\10_West_February.txt
# (28, 29)
# (92, 29)
# (120, 29)
# ./temp\10_West_January.txt
# (31, 29)
# (120, 29)
# (151, 29)
# ./temp\10_West_July.txt
# (31, 29)
# (151, 29)
# (182, 29)
# ./temp\10_West_June.txt
# (30, 29)
# (182, 29)
# (212, 29)
# ./temp\10_West_March.txt
# (31, 29)
# (212, 29)
# (243, 29)
# ./temp\10_West_May.txt
# (31, 29)
# (243, 29)
# (274, 29)
# ./temp\10_West_November.txt
# (30, 29)
# (274, 29)
# (304, 29)
# ./temp\10_West_October.txt
# (31, 29)
# (304, 29)
# (335, 29)
# ./temp\10_West_September.txt
# (30, 29)
# (335, 29)
# (365, 29)
# ./temp\11_West_April.txt
# (30, 29)
# (365, 29)
# (395, 29)
# ./temp\11_West_August.txt
# (31, 29)
# (395, 29)
# (426, 29)
# ./temp\11_West_December.txt
# (31, 29)
# (426, 29)
# (457, 29)
# ./temp\11_West_February.txt
# (29, 29)
# (457, 29)
# (486, 29)
# ./temp\11_West_January.txt
# (31, 29)
# (486, 29)
# (517, 29)
# ./temp\11_West_July.txt
# (31, 29)
# (517, 29)
# (548, 29)
# ./temp\11_West_June.txt
# (30, 29)
# (548, 29)
# (578, 29)
# ./temp\11_West_March.txt
# (31, 29)
# (578, 29)
# (609, 29)
# ./temp\11_West_May.txt
# (31, 29)
# (609, 29)
# (640, 29)
# ./temp\11_West_November.txt
# (30, 29)
# (640, 29)
# (670, 29)
# ./temp\11_West_October.txt
# (31, 29)
# (670, 29)
# (701, 29)
# ./temp\11_West_September.txt
# (30, 29)
# (701, 29)
# (731, 29)
# ./temp\12_West_April.txt
# (30, 29)
# (731, 29)
# (761, 29)
# ./temp\12_West_August.txt
# (31, 29)
# (761, 29)
# (792, 29)
# ./temp\12_West_December.txt
# (31, 29)
# (792, 29)
# (823, 29)
# ./temp\12_West_February.txt
# (28, 29)
# (823, 29)
# (851, 29)
# ./temp\12_West_January.txt
# (31, 29)
# (851, 29)
# (882, 29)
# ./temp\12_West_July.txt
# (31, 29)
# (882, 29)
# (913, 29)
# ./temp\12_West_June.txt
# (30, 29)
# (913, 29)
# (943, 29)
# ./temp\12_West_March.txt
# (31, 29)
# (943, 29)
# (974, 29)
# ./temp\12_West_May.txt
# (31, 29)
# (974, 29)
# (1005, 29)
# ./temp\12_West_November.txt
# (30, 29)
# (1005, 29)
# (1035, 29)
# ./temp\12_West_October.txt
# (31, 29)
# (1035, 29)
# (1066, 29)
# ./temp\12_West_September.txt
# (30, 29)
# (1066, 29)
# (1096, 29)
# ./temp\13_West_April.txt
# (30, 29)
# (1096, 29)
# (1126, 29)
# ./temp\13_West_August.txt
# (31, 29)
# (1126, 29)
# (1157, 29)
# ./temp\13_West_December.txt
# (31, 29)
# (1157, 29)
# (1188, 29)
# ./temp\13_West_February.txt
# (28, 29)
# (1188, 29)
# (1216, 29)
# ./temp\13_West_January.txt
# (31, 29)
# (1216, 29)
# (1247, 29)
# ./temp\13_West_July.txt
# (31, 29)
# (1247, 29)
# (1278, 29)
# ./temp\13_West_June.txt
# (30, 29)
# (1278, 29)
# (1308, 29)
# ./temp\13_West_March.txt
# (31, 29)
# (1308, 29)
# (1339, 29)
# ./temp\13_West_May.txt
# (31, 29)
# (1339, 29)
# (1370, 29)
# ./temp\13_West_November.txt
# (30, 29)
# (1370, 29)
# (1400, 29)
# ./temp\13_West_October.txt
# (31, 29)
# (1400, 29)
# (1431, 29)
# ./temp\13_West_September.txt
# (30, 29)
# (1431, 29)
# (1461, 29)
# ./temp\14_West_April.txt
# (30, 29)
# (1461, 29)
# (1491, 29)
# ./temp\14_West_August.txt
# (31, 29)
# (1491, 29)
# (1522, 29)
# ./temp\14_West_December.txt
# (31, 29)
# (1522, 29)
# (1553, 29)
# ./temp\14_West_February.txt
# (28, 29)
# (1553, 29)
# (1581, 29)
# ./temp\14_West_January.txt
# (31, 29)
# (1581, 29)
# (1612, 29)
# ./temp\14_West_July.txt
# (31, 29)
# (1612, 29)
# (1643, 29)
# ./temp\14_West_June.txt
# (30, 29)
# (1643, 29)
# (1673, 29)
# ./temp\14_West_March.txt
# (31, 29)
# (1673, 29)
# (1704, 29)
# ./temp\14_West_May.txt
# (31, 29)
# (1704, 29)
# (1735, 29)
# ./temp\14_West_November.txt
# (30, 29)
# (1735, 29)
# (1765, 29)
# ./temp\14_West_October.txt
# (31, 29)
# (1765, 29)
# (1796, 29)
# ./temp\14_West_September.txt
# (30, 29)
# (1796, 29)
# (1826, 29)
# ./temp\15_West_April.txt
# (30, 29)
# (1826, 29)
# (1856, 29)
# ./temp\15_West_August.txt
# (31, 29)
# (1856, 29)
# (1887, 29)
# ./temp\15_West_December.txt
# (31, 29)
# (1887, 29)
# (1918, 29)
# ./temp\15_West_February.txt
# (29, 29)
# (1918, 29)
# (1947, 29)
# ./temp\15_West_January.txt
# (31, 29)
# (1947, 29)
# (1978, 29)
# ./temp\15_West_July.txt
# (31, 29)
# (1978, 29)
# (2009, 29)
# ./temp\15_West_June.txt
# (30, 29)
# (2009, 29)
# (2039, 29)
# ./temp\15_West_March.txt
# (31, 29)
# (2039, 29)
# (2070, 29)
# ./temp\15_West_May.txt
# (31, 29)
# (2070, 29)
# (2101, 29)
# ./temp\15_West_November.txt
# (30, 29)
# (2101, 29)
# (2131, 29)
# ./temp\15_West_October.txt
# (31, 29)
# (2131, 29)
# (2162, 29)
# ./temp\15_West_September.txt
# (30, 29)
# (2162, 29)
# (2192, 29)
# ./temp\16_West_April.txt
# (30, 29)
# (2192, 29)
# (2222, 29)
# ./temp\16_West_August.txt
# (31, 29)
# (2222, 29)
# (2253, 29)
# ./temp\16_West_December.txt
# (31, 29)
# (2253, 29)
# (2284, 29)
# ./temp\16_West_February.txt
# (28, 29)
# (2284, 29)
# (2312, 29)
# ./temp\16_West_January.txt
# (31, 29)
# (2312, 29)
# (2343, 29)
# ./temp\16_West_July.txt
# (31, 29)
# (2343, 29)
# (2374, 29)
# ./temp\16_West_June.txt
# (30, 29)
# (2374, 29)
# (2404, 29)
# ./temp\16_West_March.txt
# (31, 29)
# (2404, 29)
# (2435, 29)
# ./temp\16_West_May.txt
# (31, 29)
# (2435, 29)
# (2466, 29)
# ./temp\16_West_November.txt
# (30, 29)
# (2466, 29)
# (2496, 29)
# ./temp\16_West_October.txt
# (31, 29)
# (2496, 29)
# (2527, 29)
# ./temp\16_West_September.txt
# (30, 29)
# (2527, 29)
# (2557, 29)
# ./temp\17_West_April.txt
# (30, 29)
# (2557, 29)
# (2587, 29)
# ./temp\17_West_August.txt
# (31, 29)
# (2587, 29)
# (2618, 29)
# ./temp\17_West_February.txt
# (28, 29)
# (2618, 29)
# (2646, 29)
# ./temp\17_West_January.txt
# (31, 29)
# (2646, 29)
# (2677, 29)
# ./temp\17_West_July.txt
# (31, 29)
# (2677, 29)
# (2708, 29)
# ./temp\17_West_June.txt
# (30, 29)
# (2708, 29)
# (2738, 29)
# ./temp\17_West_March.txt
# (31, 29)
# (2738, 29)
# (2769, 29)
# ./temp\17_West_May.txt
# (31, 29)
# (2769, 29)
# (2800, 29)
# ./temp\17_West_September.txt
# (30, 29)
# (2800, 29)
# (2830, 29)
# ./temp\1_West_April.txt
# (30, 29)
# (2830, 29)
# (2860, 29)
# ./temp\1_West_August.txt
# (31, 29)
# (2860, 29)
# (2891, 29)
# ./temp\1_West_December.txt
# (31, 29)
# (2891, 29)
# (2922, 29)
# ./temp\1_West_February.txt
# (28, 29)
# (2922, 29)
# (2950, 29)
# ./temp\1_West_January.txt
# (31, 29)
# (2950, 29)
# (2981, 29)
# ./temp\1_West_July.txt
# (31, 29)
# (2981, 29)
# (3012, 29)
# ./temp\1_West_June.txt
# (30, 29)
# (3012, 29)
# (3042, 29)
# ./temp\1_West_March.txt
# (31, 29)
# (3042, 29)
# (3073, 29)
# ./temp\1_West_May.txt
# (31, 29)
# (3073, 29)
# (3104, 29)
# ./temp\1_West_November.txt
# (30, 29)
# (3104, 29)
# (3134, 29)
# ./temp\1_West_October.txt
# (31, 29)
# (3134, 29)
# (3165, 29)
# ./temp\1_West_September.txt
# (30, 29)
# (3165, 29)
# (3195, 29)
# ./temp\2_West_April.txt
# (30, 29)
# (3195, 29)
# (3225, 29)
# ./temp\2_West_August.txt
# (31, 29)
# (3225, 29)
# (3256, 29)
# ./temp\2_West_December.txt
# (31, 29)
# (3256, 29)
# (3287, 29)
# ./temp\2_West_February.txt
# (28, 29)
# (3287, 29)
# (3315, 29)
# ./temp\2_West_January.txt
# (31, 29)
# (3315, 29)
# (3346, 29)
# ./temp\2_West_July.txt
# (31, 29)
# (3346, 29)
# (3377, 29)
# ./temp\2_West_June.txt
# (30, 29)
# (3377, 29)
# (3407, 29)
# ./temp\2_West_March.txt
# (31, 29)
# (3407, 29)
# (3438, 29)
# ./temp\2_West_May.txt
# (31, 29)
# (3438, 29)
# (3469, 29)
# ./temp\2_West_November.txt
# (30, 29)
# (3469, 29)
# (3499, 29)
# ./temp\2_West_October.txt
# (31, 29)
# (3499, 29)
# (3530, 29)
# ./temp\2_West_September.txt
# (30, 29)
# (3530, 29)
# (3560, 29)
# ./temp\3_West_April.txt
# (30, 29)
# (3560, 29)
# (3590, 29)
# ./temp\3_West_August.txt
# (31, 29)
# (3590, 29)
# (3621, 29)
# ./temp\3_West_December.txt
# (31, 29)
# (3621, 29)
# (3652, 29)
# ./temp\3_West_February.txt
# (29, 29)
# (3652, 29)
# (3681, 29)
# ./temp\3_West_January.txt
# (31, 29)
# (3681, 29)
# (3712, 29)
# ./temp\3_West_July.txt
# (31, 29)
# (3712, 29)
# (3743, 29)
# ./temp\3_West_June.txt
# (30, 29)
# (3743, 29)
# (3773, 29)
# ./temp\3_West_March.txt
# (31, 29)
# (3773, 29)
# (3804, 29)
# ./temp\3_West_May.txt
# (31, 29)
# (3804, 29)
# (3835, 29)
# ./temp\3_West_November.txt
# (30, 29)
# (3835, 29)
# (3865, 29)
# ./temp\3_West_October.txt
# (31, 29)
# (3865, 29)
# (3896, 29)
# ./temp\3_West_September.txt
# (30, 29)
# (3896, 29)
# (3926, 29)
# ./temp\4_West_April.txt
# (30, 29)
# (3926, 29)
# (3956, 29)
# ./temp\4_West_August.txt
# (31, 29)
# (3956, 29)
# (3987, 29)
# ./temp\4_West_December.txt
# (31, 29)
# (3987, 29)
# (4018, 29)
# ./temp\4_West_February.txt
# (28, 29)
# (4018, 29)
# (4046, 29)
# ./temp\4_West_January.txt
# (31, 29)
# (4046, 29)
# (4077, 29)
# ./temp\4_West_July.txt
# (31, 29)
# (4077, 29)
# (4108, 29)
# ./temp\4_West_June.txt
# (30, 29)
# (4108, 29)
# (4138, 29)
# ./temp\4_West_March.txt
# (31, 29)
# (4138, 29)
# (4169, 29)
# ./temp\4_West_May.txt
# (31, 29)
# (4169, 29)
# (4200, 29)
# ./temp\4_West_November.txt
# (30, 29)
# (4200, 29)
# (4230, 29)
# ./temp\4_West_October.txt
# (31, 29)
# (4230, 29)
# (4261, 29)
# ./temp\4_West_September.txt
# (30, 29)
# (4261, 29)
# (4291, 29)
# ./temp\5_West_April.txt
# (30, 29)
# (4291, 29)
# (4321, 29)
# ./temp\5_West_August.txt
# (31, 29)
# (4321, 29)
# (4352, 29)
# ./temp\5_West_December.txt
# (31, 29)
# (4352, 29)
# (4383, 29)
# ./temp\5_West_February.txt
# (28, 29)
# (4383, 29)
# (4411, 29)
# ./temp\5_West_January.txt
# (31, 29)
# (4411, 29)
# (4442, 29)
# ./temp\5_West_July.txt
# (31, 29)
# (4442, 29)
# (4473, 29)
# ./temp\5_West_June.txt
# (30, 29)
# (4473, 29)
# (4503, 29)
# ./temp\5_West_March.txt
# (31, 29)
# (4503, 29)
# (4534, 29)
# ./temp\5_West_May.txt
# (31, 29)
# (4534, 29)
# (4565, 29)
# ./temp\5_West_November.txt
# (30, 29)
# (4565, 29)
# (4595, 29)
# ./temp\5_West_October.txt
# (31, 29)
# (4595, 29)
# (4626, 29)
# ./temp\5_West_September.txt
# (30, 29)
# (4626, 29)
# (4656, 29)
# ./temp\6_West_April.txt
# (30, 29)
# (4656, 29)
# (4686, 29)
# ./temp\6_West_August.txt
# (31, 29)
# (4686, 29)
# (4717, 29)
# ./temp\6_West_December.txt
# (31, 29)
# (4717, 29)
# (4748, 29)
# ./temp\6_West_February.txt
# (28, 29)
# (4748, 29)
# (4776, 29)
# ./temp\6_West_January.txt
# (31, 29)
# (4776, 29)
# (4807, 29)
# ./temp\6_West_July.txt
# (31, 29)
# (4807, 29)
# (4838, 29)
# ./temp\6_West_June.txt
# (30, 29)
# (4838, 29)
# (4868, 29)
# ./temp\6_West_March.txt
# (31, 29)
# (4868, 29)
# (4899, 29)
# ./temp\6_West_May.txt
# (31, 29)
# (4899, 29)
# (4930, 29)
# ./temp\6_West_November.txt
# (30, 29)
# (4930, 29)
# (4960, 29)
# ./temp\6_West_October.txt
# (31, 29)
# (4960, 29)
# (4991, 29)
# ./temp\6_West_September.txt
# (30, 29)
# (4991, 29)
# (5021, 29)
# ./temp\7_West_April.txt
# (30, 29)
# (5021, 29)
# (5051, 29)
# ./temp\7_West_August.txt
# (31, 29)
# (5051, 29)
# (5082, 29)
# ./temp\7_West_December.txt
# (31, 29)
# (5082, 29)
# (5113, 29)
# ./temp\7_West_February.txt
# (29, 29)
# (5113, 29)
# (5142, 29)
# ./temp\7_West_January.txt
# (31, 29)
# (5142, 29)
# (5173, 29)
# ./temp\7_West_July.txt
# (31, 29)
# (5173, 29)
# (5204, 29)
# ./temp\7_West_June.txt
# (30, 29)
# (5204, 29)
# (5234, 29)
# ./temp\7_West_March.txt
# (31, 29)
# (5234, 29)
# (5265, 29)
# ./temp\7_West_May.txt
# (31, 29)
# (5265, 29)
# (5296, 29)
# ./temp\7_West_November.txt
# (30, 29)
# (5296, 29)
# (5326, 29)
# ./temp\7_West_October.txt
# (31, 29)
# (5326, 29)
# (5357, 29)
# ./temp\7_West_September.txt
# (30, 29)
# (5357, 29)
# (5387, 29)
# ./temp\8_West_April.txt
# (30, 29)
# (5387, 29)
# (5417, 29)
# ./temp\8_West_August.txt
# (31, 29)
# (5417, 29)
# (5448, 29)
# ./temp\8_West_December.txt
# (31, 29)
# (5448, 29)
# (5479, 29)
# ./temp\8_West_February.txt
# (28, 29)
# (5479, 29)
# (5507, 29)
# ./temp\8_West_January.txt
# (31, 29)
# (5507, 29)
# (5538, 29)
# ./temp\8_West_July.txt
# (31, 29)
# (5538, 29)
# (5569, 29)
# ./temp\8_West_June.txt
# (30, 29)
# (5569, 29)
# (5599, 29)
# ./temp\8_West_March.txt
# (31, 29)
# (5599, 29)
# (5630, 29)
# ./temp\8_West_May.txt
# (31, 29)
# (5630, 29)
# (5661, 29)
# ./temp\8_West_November.txt
# (30, 29)
# (5661, 29)
# (5691, 29)
# ./temp\8_West_October.txt
# (31, 29)
# (5691, 29)
# (5722, 29)
# ./temp\8_West_September.txt
# (30, 29)
# (5722, 29)
# (5752, 29)
# ./temp\9_West_April.txt
# (30, 29)
# (5752, 29)
# (5782, 29)
# ./temp\9_West_August.txt
# (31, 29)
# (5782, 29)
# (5813, 29)
# ./temp\9_West_December.txt
# (31, 29)
# (5813, 29)
# (5844, 29)
# ./temp\9_West_February.txt
# (28, 29)
# (5844, 29)
# (5872, 29)
# ./temp\9_West_January.txt
# (31, 29)
# (5872, 29)
# (5903, 29)
# ./temp\9_West_July.txt
# (31, 29)
# (5903, 29)
# (5934, 29)
# ./temp\9_West_June.txt
# (30, 29)
# (5934, 29)
# (5964, 29)
# ./temp\9_West_March.txt
# (31, 29)
# (5964, 29)
# (5995, 29)
# ./temp\9_West_May.txt
# (31, 29)
# (5995, 29)
# (6026, 29)
# ./temp\9_West_November.txt
# (30, 29)
# (6026, 29)
# (6056, 29)
# ./temp\9_West_October.txt
# (31, 29)
# (6056, 29)
# (6087, 29)
# ./temp\9_West_September.txt
# (30, 29)
# (6087, 29)
# (6117, 29)

# %%
# let's try melting the data into a single continuous time series
melt = pd.melt(master_df, id_vars=['Date'], value_vars=['01:00', '02:00', '03:00', '04:00', '05:00', 
                         '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', 
                         '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', 
                         '20:00', '21:00', '22:00', '23:00', '00:00'], var_name='Hour', value_name='Traffic_Volume')

# %%
melt['ds'] = melt['Date'].astype('str') + ' ' + melt['Hour']
melt['ds'] = pd.to_datetime(melt['ds'])
del melt['Date']
del melt['Hour']

# %%
melt.sort_values(by=['ds'], inplace=True)
melt.set_index('ds', inplace=True)

# %%
melt.to_csv('ts_traffic.csv')

# %%
import pandas as pd

# wrangle weather data
weather = pd.read_csv('./supplemental_data/weather.csv')
weather['ds'] = pd.to_datetime(weather['ds'], format='%Y-%m-%d %H:%M:%S +0000 UTC')
weather.fillna(0, inplace=True)

# %%
from pytz import all_timezones

# Set starting time zone
weather['ds'] = weather['ds'].dt.tz_localize('UTC')
# convert to CST
weather['ds'] = weather['ds'].dt.tz_convert('US/Central')

# %%
weather.to_csv('weather_cst.csv', index=False)
